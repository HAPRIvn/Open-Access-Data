# %% [markdown]
# # Import COVID-19 Data cases from
#
# https://api.covid19india.org/

# %% [markdown]
# ## Import relevent packages

# %%
import os
import requests
import pandas as pd
from openpyxl import load_workbook

# %% [markdown]
# ## Set working directory

# %%
os.chdir(r'C:\Users\NXDin\Dropbox (Vo Tat Thang)\[0][Master]Database\(1)Library_of_Data\Web-Scrap') # Provide the path here
#os.chdir('D:\Dropbox (Vo Tat Thang)\[0][Master]Database\(1)Library_of_Data\Web-Scrap') # Provide the path here

# %% [markdown]
# ## Set up URL

# %%
data_url = ['https://api.covid19india.org/raw_data1.json',
            'https://api.covid19india.org/raw_data2.json',
            'https://api.covid19india.org/raw_data3.json',
            'https://api.covid19india.org/raw_data4.json'
           ]

# %% [markdown]
# ## Get data from the server and convert to JSON format

# %%
i = 1
for url in data_url:

    response = requests.get(url)
    response_json = response.json()
    data_json = response_json['raw_data']

    print("Crawling: {}".format(url))
    
    #Create new excel file for first sheet
    if i == 1:

        writer = pd.ExcelWriter(os.path.join("DATARAW", 'COVID19_India.xlsx'), engine = 'openpyxl')
        df1 = pd.DataFrame(data_json)
        df1.to_excel(writer \
                    , sheet_name = str(i) \
                    , index = False)
        writer.save()
        writer.close() 

    #Append new sheet to the newly created excel file
    elif i != 1: 

        book = load_workbook(os.path.join("DATARAW", 'COVID19_India.xlsx'))
        writer = pd.ExcelWriter(os.path.join("DATARAW", 'COVID19_India.xlsx'), engine = 'openpyxl')
        writer.book = book
        df1 = pd.DataFrame(data_json)
        df1.to_excel(writer \
                    , sheet_name = str(i) \
                    , index = False)
        writer.save()
        writer.close() 

    else:

        print("Something is wrong")

    i += 1
# Out:
# Crawling: https://api.covid19india.org/raw_data1.json
# Crawling: https://api.covid19india.org/raw_data2.json
# Crawling: https://api.covid19india.org/raw_data3.json
# Crawling: https://api.covid19india.org/raw_data4.json

# %% [markdown]
# ## Check crawl accuracy

# %%
df = pd.read_excel(os.path.join("DATARAW", 'COVID19_India.xlsx'), sheet_name='4', nrows=10)
display(df)
# Out:
#    agebracket  contractedfromwhichpatientsuspected currentstatus  \
# 0         NaN                                  NaN  Hospitalized
# 1         NaN                                  NaN  Hospitalized
# 2         NaN                                  NaN  Hospitalized
# 3         NaN                                  NaN  Hospitalized
# 4         NaN                                  NaN  Hospitalized
# 5         NaN                                  NaN  Hospitalized
# 6         NaN                                  NaN      Deceased
# 7         NaN                                  NaN     Recovered
# 8         NaN                                  NaN     Recovered
# 9         NaN                                  NaN     Recovered
#
#   dateannounced  detectedcity detecteddistrict detectedstate  entryid  gender  \
# 0    10/05/2020           NaN            Ajmer     Rajasthan    10009     NaN
# 1    10/05/2020           NaN        Dungarpur     Rajasthan    10010     NaN
# 2    10/05/2020           NaN           Jaipur     Rajasthan    10011     NaN
# 3    10/05/2020           NaN             Kota     Rajasthan    10012     NaN
# 4    10/05/2020           NaN             Pali     Rajasthan    10013     NaN
# 5    10/05/2020           NaN          Udaipur     Rajasthan    10014     NaN
# 6    10/05/2020           NaN           Jaipur     Rajasthan    10015     NaN
# 7    10/05/2020           NaN         Banswara     Rajasthan    10016     NaN
# 8    10/05/2020           NaN        Bharatpur     Rajasthan    10017     NaN
# 9    10/05/2020           NaN      Chittorgarh     Rajasthan    10018     NaN
#
#    nationality  notes  numcases  patientnumber  \
# 0          NaN    NaN         2          37900
# 1          NaN    NaN         1          37901
# 2          NaN    NaN        10          37902
# 3          NaN    NaN         9          37903
# 4          NaN    NaN         2          37904
# 5          NaN    NaN         9          37905
# 6          NaN    NaN         1          37906
# 7          NaN    NaN         4          37907
# 8          NaN    NaN         2          37908
# 9          NaN    NaN         6          37909
#
#                                              source1  source2  source3  \
# 0  https://twitter.com/ANI/status/125933138485177...      NaN      NaN
# 1  https://twitter.com/ANI/status/125933138485177...      NaN      NaN
# 2  https://twitter.com/ANI/status/125933138485177...      NaN      NaN
# 3  https://twitter.com/ANI/status/125933138485177...      NaN      NaN
# 4  https://twitter.com/ANI/status/125933138485177...      NaN      NaN
# 5  https://twitter.com/ANI/status/125933138485177...      NaN      NaN
# 6  https://twitter.com/ANI/status/125933138485177...      NaN      NaN
# 7  https://twitter.com/ANI/status/125933138485177...      NaN      NaN
# 8  https://twitter.com/ANI/status/125933138485177...      NaN      NaN
# 9  https://twitter.com/ANI/status/125933138485177...      NaN      NaN
#
#   statecode  statepatientnumber  statuschangedate  typeoftransmission
# 0        RJ                 NaN               NaN                 NaN
# 1        RJ                 NaN               NaN                 NaN
# 2        RJ                 NaN               NaN                 NaN
# 3        RJ                 NaN               NaN                 NaN
# 4        RJ                 NaN               NaN                 NaN
# 5        RJ                 NaN               NaN                 NaN
# 6        RJ                 NaN               NaN                 NaN
# 7        RJ                 NaN               NaN                 NaN
# 8        RJ                 NaN               NaN                 NaN
# 9        RJ                 NaN               NaN                 NaN

# %% [markdown]
# ## Reference
# 1. https://stackoverflow.com/questions/12965203/how-to-get-json-from-webpage-into-python-script
# 2. https://stackoverflow.com/questions/15008970/way-to-read-first-few-lines-for-pandas-dataframe
